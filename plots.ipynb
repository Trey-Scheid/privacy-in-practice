# %%
from SGD import SGD as MySGD
from GD import GD as MyGD

# %%
obj=MySGD()
obj2=MyGD()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
obj.diffNoisePlot(2)

# %%
obj.diffLearningRatesPlot(2)

# %%
#list [.5,1,1.5,2]
SGD_epsilon_errors=obj.epsPoints()
SGD_epsilon_errors
# Out:
# [array([0.20339143]),
#  array([0.17814414]),
#  array([0.16589732]),
#  array([0.15204899])]

# %%
obj2.diffNoisePlot(2)

# %%
obj2.diffLearningRatesPlot(2)
